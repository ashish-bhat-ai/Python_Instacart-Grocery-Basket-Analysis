# %%
# importing libs
import pandas as pd
import numpy as pp
import os

# %%
# defining path
path = r'D:\Python_project\050924_Instakart Basket analysis'

# %%
# importing files to dataframes
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# SystemError: deallocated bytearray object has exported buffers
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 # importing files to dataframes
# ----> 2 df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
#       3 df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)
#
# File D:\Installs\Anaconda\Lib\site-packages\pandas\io\pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     199     with warnings.catch_warnings(record=True):
#     200         # We want to silence any warnings about, e.g. moved modules.
# ...

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  number_of_orders  weekday  \
# 0           0   2539329        1                 1        2
# 1           0   2539329        1                 1        2
# 2           0   2539329        1                 1        2
# 3           0   2539329        1                 1        2
# 4           0   2539329        1                 1        2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
df_orders_products_combined = df_orders_products_combined.drop(df_orders_products_combined.columns[0],axis = 1)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  number_of_orders  weekday  order_hour_of_day  \
# 0   2539329        1                 1        2                  8
# 1   2539329        1                 1        2                  8
# 2   2539329        1                 1        2                  8
# 3   2539329        1                 1        2                  8
# 4   2539329        1                 1        2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_orders_products_combined = df_orders_products_combined.drop(df_orders_products_combined.columns[9],axis = 1)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  number_of_orders  weekday  order_hour_of_day  \
# 0   2539329        1                 1        2                  8
# 1   2539329        1                 1        2                  8
# 2   2539329        1                 1        2                  8
# 3   2539329        1                 1        2                  8
# 4   2539329        1                 1        2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods = df_prods.drop(df_prods.columns[0],axis=1)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# In order to combine the data sets , we will need a common key which lets say could be product_id in this case

# %%
df_ords_prods_merge = df_prods.merge(df_orders_products_combined, on = 'product_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_ords_prods_merge = df_prods.merge(df_orders_products_combined, on = 'product_id', indicator = True)
#
# NameError: name 'df_prods' is not defined
